# %% [markdown]
# <a href="https://colab.research.google.com/github/suryapratapkhuntia/Machine_learning_real_world_projects_for_practice/blob/main/suv_purchased_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("/content/SUV CAR DATASET.csv")
df.sample(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 53   15671655  Female   35            23000          0
# 71   15726358  Female   24            27000          0
# 283  15663249  Female   52            21000          1
# 225  15622171    Male   37            53000          0
# 44   15715541  Female   28            84000          0

# %%
df.drop("User ID", axis=1, inplace=True)

# %%
df.sample(5)
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 213    Male   35            58000          0
# 289  Female   37            78000          1
# 163    Male   35            38000          0
# 180    Male   26            16000          0
# 338  Female   38            55000          0

# %%
df.isnull().sum()
# Out:
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder()

# %%
df["Gender"] = oe.fit_transform(df[["Gender"]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_sc=StandardScaler()
df[["Gender", "Age", "EstimatedSalary"]] = standard_sc.fit_transform(df[["Gender", "Age", "EstimatedSalary"]])

# %%
x=df.drop("Purchased", axis=1)
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,VotingClassifier,BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
model={
    "LogisticRegression":LogisticRegression(),
    "DecisionTreeClassifier":DecisionTreeClassifier(),
    "RandomForestClassifier":RandomForestClassifier(),
    "AdaBoostClassifier":AdaBoostClassifier(),
    "GradientBoostingClassifier":GradientBoostingClassifier(),
    "KNeighborsClassifier":KNeighborsClassifier(),
    "SVC":SVC()
}

for model,model_obj in model.items():
  model_obj.fit(x_train, y_train)
  y_pred=model_obj.predict(x_test)
  print(f"{model} : {accuracy_score(y_test, y_pred)}")
# Out:
# LogisticRegression : 0.7375
# DecisionTreeClassifier : 0.8375
# RandomForestClassifier : 0.8375
# AdaBoostClassifier : 0.85
# GradientBoostingClassifier : 0.8625
# KNeighborsClassifier : 0.8625
# SVC : 0.8125

# %%
bagg_clf=BaggingClassifier(estimator=GradientBoostingClassifier(), n_estimators=10, random_state=1)
bagg_clf.fit(x_train, y_train)
y_pred=bagg_clf.predict(x_test)
print(f"Bagging Classifier : {accuracy_score(y_test, y_pred)}")
# Out:
# Bagging Classifier : 0.8875

# %%
def prediction(Gender, Age, EstimatedSalary):

  gender_encoded = oe.transform([[Gender]])

  user_data = np.array([[gender_encoded[0][0], Age, EstimatedSalary]])
  user_data_scaled = standard_sc.transform(user_data)

  prediction = bagg_clf.predict(user_data_scaled)
  if prediction[0] == 1:
    print("User will buy the SUV")
  else:
    print("User will not buy the SUV")
  return prediction

# %%
# Call the prediction function with correct arguments
prediction('Male', 18, 1000000)
# Out:
# User will buy the SUV
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# array([1])
